# %%
# Цель работы: Провести полный цикл исследования данных на реальном датасете: от поиска данных до построения прогнозной модели и формулирования бизнес-выводов.
# 
# Источники данных:
# - Kaggle (https://www.kaggle.com/)
# - Gapminder (https://www.gapminder.org/)
# - Проект "Если быть точным" (https://tochno.st/)
# - Росстат (https://rosstat.gov.ru/)
# - Всемирный банк (https://data.worldbank.org/)
# - и другие
# ! Проверьте, не являются ли данные игрушечными, синтетическими
# 
# Постановка задачи: 
# - О чем ваш датасет 
# - Какую проблему вы хотите решить
# 
# Предобработка данных: 
# - пропуски 
# - типы данных 
# - и другие
# 
# Разведочный анализ данных (EDA):
# Искать интересные факты и инсайты в данных
# - Группировка
# - Фильтрация
# - Визуализация
# 
# Машинное обучение
# - Сформируйте гипотезу
# - Постройте модель линейной регрессии
# - Рассчитайте метрики
# 
# Выводы
#
# Сделать презентацию и защитить проект.
# 
# 
# Критерии оценки:
# 1. Техническая реализация (40%)
# - Загрузка и типы: Данные загружены корректно, даты переведены в datetime, числа не являются строками (object).
# - Чистка данных: Обработаны пропуски.
# - Манипуляция: Использованы сложные методы: groupby, merge (если было несколько таблиц), apply, pivot_table.
# - Код: Код читаемый, переменные названы понятно (не a, b, df1)
# 
# 2. Визуализация и Анализ (30%)
# - Качество графиков: Графики наглядные: есть заголовки (Title), подписаны оси (Labels), есть легенда. Выбраны правильные типы графиков.
# - Логика исследования: Анализ не хаотичен. Нет графиков "ради того, чтобы было".
# 
# 3. Моделирование и Выводы (30%)
# - Корректность ML: Правильное разделение на X и y. Модель обучена. Метрики посчитаны.
# - Интерпретация. Студент понимает физический смысл коэффициентов регрессии (что на что влияет) и метрик (хорошая модель или плохая).
# - Выводы. Работа заканчивается осмысленным итогом.
