# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/test.xlsx')

# %%
df
# Out:
#      ф     и          п
# 0    5    ап       1.54
# 1    6     р       1.67
# 2  756   апр       1.56
# 3    7   апр       5.00
# 4  567    ап       0.00
# 5  566  рапр  676767.45
