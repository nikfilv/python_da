# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/world_population.csv')

# %%
df.head(2)
# Out:
#    Rank CCA3 Country/Territory Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan   Kabul      Asia         41128771
# 1   138  ALB           Albania  Tirana    Europe          2842321
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# 1            98.8702       0.9957                         0.04

# %%
df.tail()
# Out:
#      Rank CCA3  Country/Territory   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country/Territory               object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
type(1)
# Out:
# int

# %%
type('Hello, world!')
# Out:
# str

# %%
type(df['Country/Territory'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Country/Territory']
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
#              ...
# 229    Wallis and Futuna
# 230       Western Sahara
# 231                Yemen
# 232               Zambia
# 233             Zimbabwe
# Name: Country/Territory, Length: 234, dtype: object

# %%
df[['Country/Territory', '2022 Population']]
# Out:
#      Country/Territory  2022 Population
# 0          Afghanistan         41128771
# 1              Albania          2842321
# 2              Algeria         44903225
# 3       American Samoa            44273
# 4              Andorra            79824
# ..                 ...              ...
# 229  Wallis and Futuna            11572
# 230     Western Sahara           575986
# 231              Yemen         33696614
# 232             Zambia         20017675
# 233           Zimbabwe         16320537
#
# [234 rows x 2 columns]

# %%
df.sort_values('2022 Population')
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 226   234  VAT      Vatican City      Vatican City         Europe
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 150   232  NIU              Niue             Alofi        Oceania
# 64    231  FLK  Falkland Islands           Stanley  South America
# 137   230  MSR        Montserrat            Brades  North America
# ..    ...  ...               ...               ...            ...
# 156     5  PAK          Pakistan         Islamabad           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 92      2  IND             India         New Delhi           Asia
# 41      1  CHN             China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226              510              520              564              596
# ...

# %%
df.head(10).sort_values('2022 Population', ascending=False).tail(2)
# Out:
#    Rank CCA3 Country/Territory     Capital      Continent  2022 Population  \
# 3   213  ASM    American Samoa   Pago Pago        Oceania            44273
# 6   224  AIA          Anguilla  The Valley  North America            15857
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 3            46189            51368            54849            58230
# 6            15585            14525            13172            11047
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 3            47818            32886            27075         199
# 6             8316             6560             6283          91
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 3           222.4774       0.9831                          0.0
# 6           174.2527       1.0066                          0.0

# %%
df[ df['Continent'] == 'Europe' ].sort_values('2022 Population', ascending=False).head(10)
# Out:
#      Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 171     9  RUS            Russia     Moscow    Europe        144713314
# 74     19  DEU           Germany     Berlin    Europe         83369843
# 220    21  GBR    United Kingdom     London    Europe         67508936
# 68     23  FRA            France      Paris    Europe         64626628
# 99     25  ITA             Italy       Rome    Europe         59037474
# 196    30  ESP             Spain     Madrid    Europe         47558630
# 164    37  POL            Poland     Warsaw    Europe         39857145
# 218    38  UKR           Ukraine       Kiev    Europe         39701739
# 170    64  ROU           Romania  Bucharest    Europe         19659267
# 144    71  NLD       Netherlands  Amsterdam    Europe         17564014
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 171        145617329        144668389        143242599        146844839
# ...

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
df_america = df[ (df['Continent'] == 'North America') | (df['Continent'] == 'South America')]

# %%
df_america.sort_values('2020 Population', ascending=False).head(10)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 221     3  USA     United States  Washington, D.C.  North America
# 27      7  BRA            Brazil          Brasilia  South America
# 131    10  MEX            Mexico       Mexico City  North America
# 42     28  COL          Colombia            Bogota  South America
# 8      33  ARG         Argentina      Buenos Aires  South America
# 35     39  CAN            Canada            Ottawa  North America
# 162    44  PER              Peru              Lima  South America
# 227    51  VEN         Venezuela           Caracas  South America
# 40     65  CHL             Chile          Santiago  South America
# 56     67  ECU           Ecuador             Quito  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 221        338289857        335942003        324607776        311182845
# 27         215313498        213196304        205188205        196353492
# ...

# %%
df[['Area (km²)', 'Density (per km²)']].describe()
# Out:
#          Area (km²)  Density (per km²)
# count  2.340000e+02         234.000000
# mean   5.814494e+05         452.127044
# std    1.761841e+06        2066.121904
# min    1.000000e+00           0.026100
# 25%    2.650000e+03          38.417875
# 50%    8.119950e+04          95.346750
# 75%    4.304258e+05         238.933250
# max    1.709824e+07       23172.266700

# %%
df[ (df['Area (km²)'] <= 500000) & (df['Density (per km²)'] >= 452) ].sort_values('2022 Population', ascending=False)
# Out:
#      Rank CCA3 Country/Territory            Capital      Continent  \
# 16      8  BGD        Bangladesh              Dhaka           Asia
# 194    29  KOR       South Korea              Seoul           Asia
# 203    57  TWN            Taiwan             Taipei           Asia
# 172    76  RWA            Rwanda             Kigali         Africa
# 32     78  BDI           Burundi          Bujumbura         Africa
# 89    104  HKG         Hong Kong          Hong Kong           Asia
# 187   113  SGP         Singapore          Singapore           Asia
# 112   119  LBN           Lebanon             Beirut           Asia
# 158   122  PSE         Palestine           Ramallah           Asia
# 15    154  BHR           Bahrain             Manama           Asia
# 129   157  MUS         Mauritius         Port Louis         Africa
# 119   167  MAC             Macau  Concelho de Macau           Asia
# 125   173  MLT             Malta           Valletta         Europe
# ...

# %%
df[:-5]
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 0      36  AFG       Afghanistan             Kabul           Asia
# 1     138  ALB           Albania            Tirana         Europe
# 2      34  DZA           Algeria           Algiers         Africa
# 3     213  ASM    American Samoa         Pago Pago        Oceania
# 4     203  AND           Andorra  Andorra la Vella         Europe
# ..    ...  ...               ...               ...            ...
# 224    43  UZB        Uzbekistan          Tashkent           Asia
# 225   181  VUT           Vanuatu         Port-Vila        Oceania
# 226   234  VAT      Vatican City      Vatican City         Europe
# 227    51  VEN         Venezuela           Caracas  South America
# 228    16  VNM           Vietnam             Hanoi           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# ...

# %%
df['dif 2022 - 2020'] = df['2022 Population'] - df['2020 Population']

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.to_csv('../data/processed/pop.csv')
