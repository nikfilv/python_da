# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/googleplaystore.csv')

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0      159  19M   10,000+  Free     0       Everyone
# 1      967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df.tail(1)
# Out:
#                                                  App   Category  Rating  \
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#        Reviews Size     Installs  Type Price Content Rating     Genres  \
# 10840   398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#         Last Updated         Current Ver         Android Ver
# 10840  July 25, 2018  Varies with device  Varies with device

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
type(1)
# Out:
# int

# %%
type(1.2)
# Out:
# float

# %%
type('dfgfg')
# Out:
# str

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
type(df['App'])
# Out:
# pandas.core.series.Series

# %%
df[ ['App', 'Rating']  ]
# Out:
#                                                      App  Rating
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     4.1
# 1                                    Coloring book moana     3.9
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7
# 3                                  Sketch - Draw & Paint     4.5
# 4                  Pixel Draw - Number Art Coloring Book     4.3
# ...                                                  ...     ...
# 10836                                   Sya9a Maroc - FR     4.5
# 10837                   Fr. Mike Schmitz Audio Teachings     5.0
# 10838                             Parkinson Exercices FR     NaN
# 10839                      The SCP Foundation DB fr nn5n     4.5
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     4.5
#
# [10841 rows x 2 columns]

# %%
df.sort_values('Reviews').head(10)
# Out:
#                                              App            Category  Rating  \
# 9964                                 SpeedApp EV   AUTO_AND_VEHICLES     NaN
# 9058          iCluster - The DX-Cluster database       COMMUNICATION     NaN
# 9030                              KeePass DX Pro               TOOLS     NaN
# 9015                                Bodyworks DW  HEALTH_AND_FITNESS     NaN
# 9014                   DW Uninstall Applications               TOOLS     NaN
# 9009                                DW Streaming              SOCIAL     NaN
# 10004                          EW MOTION THERAPY  HEALTH_AND_FITNESS     NaN
# 10835                                   FR Forms            BUSINESS     NaN
# 10009  NATIVE ENTERTAINMENT MAGAZINE - ISSUE # 1  NEWS_AND_MAGAZINES     NaN
# 9997                                    EW Login            BUSINESS     NaN
#
#        Reviews                Size Installs  Type  Price Content Rating  \
# ...

# %%
df.sort_values('Reviews', ascending=False).head(10)
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 3943                                  Facebook         SOCIAL     4.1
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 2604                                 Instagram         SOCIAL     4.5
# 2545                                 Instagram         SOCIAL     4.5
# 2611                                 Instagram         SOCIAL     4.5
# 3909                                 Instagram         SOCIAL     4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 2544  78158306  Varies with device  1,000,000,000+  Free     0           Teen
# ...

# %%
df[  df['Category'] == 'SOCIAL'].sort_values('Reviews', ascending=False).head(20)
# Out:
#                                  App Category  Rating   Reviews  \
# 2544                        Facebook   SOCIAL     4.1  78158306
# 3943                        Facebook   SOCIAL     4.1  78128208
# 2604                       Instagram   SOCIAL     4.5  66577446
# 2545                       Instagram   SOCIAL     4.5  66577313
# 2611                       Instagram   SOCIAL     4.5  66577313
# 3909                       Instagram   SOCIAL     4.5  66509917
# 2610                        Snapchat   SOCIAL     4.0  17015352
# 2550                        Snapchat   SOCIAL     4.0  17014787
# 2603                        Snapchat   SOCIAL     4.0  17014705
# 3870                        Snapchat   SOCIAL     4.0  17000166
# 2546                   Facebook Lite   SOCIAL     4.3   8606259
# 4105                   Facebook Lite   SOCIAL     4.3   8595964
# 6373                              VK   SOCIAL     3.8   5793284
# 3945  Tik Tok - including musical.ly   SOCIAL     4.4   5637451
# ...

# %%
df[  df['Reviews'] < 3000000 ].sort_values('Reviews', ascending=False).head(20)
# Out:
#                                                     App             Category  \
# 2548                                             Tumblr               SOCIAL
# 2599                                             Tumblr               SOCIAL
# 4586                                             Tumblr               SOCIAL
# 4715                               Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# 139                                Wattpad 📖 Free Books  BOOKS_AND_REFERENCE
# 9166                       Modern Combat 5: eSports FPS                 GAME
# 395          GO SMS Pro - Messenger, Free Themes, Emoji        COMMUNICATION
# 6849                                Bubble Witch 2 Saga               FAMILY
# 4587                                             Tinder            LIFESTYLE
# 2784  eBay: Buy & Sell this Summer - Discover Deals ...             SHOPPING
# 2738  eBay: Buy & Sell this Summer - Discover Deals ...             SHOPPING
# ...

# %%
df[ (df['Category'] == 'SOCIAL') & ( df['Reviews'] < 3000000 ) ].sort_values('Reviews', ascending=False).head(5)
# Out:
#                           App Category  Rating  Reviews                Size  \
# 2548                   Tumblr   SOCIAL     4.4  2955326  Varies with device
# 2599                   Tumblr   SOCIAL     4.4  2955325  Varies with device
# 4586                   Tumblr   SOCIAL     4.4  2953886  Varies with device
# 3951  BIGO LIVE - Live Stream   SOCIAL     4.4  2349421                 39M
# 2622                     Path   SOCIAL     4.4  1520959  Varies with device
#
#           Installs  Type Price Content Rating  Genres    Last Updated  \
# 2548  100,000,000+  Free     0     Mature 17+  Social  August 1, 2018
# 2599  100,000,000+  Free     0     Mature 17+  Social  August 1, 2018
# 4586  100,000,000+  Free     0     Mature 17+  Social  August 1, 2018
# 3951  100,000,000+  Free     0           Teen  Social   July 27, 2018
# 2622   10,000,000+  Free     0           Teen  Social     May 9, 2018
#
#              Current Ver         Android Ver
# ...

# %%
df[ (df['Category'] == 'HOUSE_AND_HOME') | (df['Category'] == 'FINANCE')].sort_values('Reviews', ascending=False).head(5)
# Out:
#                  App Category  Rating  Reviews                Size  \
# 1173    Chase Mobile  FINANCE     4.6  1374549                 32M
# 1088  Bank of Brazil  FINANCE     4.5  1336246                 39M
# 1059       Itau bank  FINANCE     4.2   957973                 40M
# 7455    Credit Karma  FINANCE     4.7   706618  Varies with device
# 1114    Credit Karma  FINANCE     4.7   706302  Varies with device
#
#          Installs  Type Price Content Rating   Genres    Last Updated  \
# 1173  10,000,000+  Free     0       Everyone  Finance   July 23, 2018
# 1088  10,000,000+  Free     0       Everyone  Finance  August 3, 2018
# 1059  10,000,000+  Free     0       Everyone  Finance   July 30, 2018
# 7455  10,000,000+  Free     0       Everyone  Finance   July 31, 2018
# 1114  10,000,000+  Free     0       Everyone  Finance   July 31, 2018
#
#              Current Ver         Android Ver
# 1173                3.52          5.0 and up
# 1088            6.39.1.4          4.1 and up
# ...

# %%
df['Category|Genres'] = df['Category'] + ' | ' + df['Genres']

# %%
df['Reviews/Rating'] = df['Reviews'] / df['Rating']

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.to_csv('../data/processed/app.csv')
